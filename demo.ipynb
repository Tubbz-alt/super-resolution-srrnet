# %%
import utilv2 as util
import torch 

'''
This file loads the preloaded weights into the device.
And upscales and image.

For thraining 4GB GPU us required, or change the device to cpu.
'''

model = torch.load('checkpoints/model_2020_05_11_14:28:56_d32_b12.model').cpu()

# %%
util.demonstrate('demo/img5.jpeg', model)
